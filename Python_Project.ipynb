# %% [markdown]
# <a href="https://colab.research.google.com/github/AdriPV17/Colab-Python-Project/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %% [markdown]
# OS library is used to search files and display information Python OS module provides easy functions that allow us to interact and get Operating System information and even control processes up to a limit.
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %%
list_file = os.listdir("/content/drive/MyDrive/Python/Sales")
display(list_file)      #list files in Sales folder / creates a variable list_file
# Out:
# ['Sales- Toronto.csv',
#  'Returns - Vancouver.csv',
#  'Returns - Toronto.csv',
#  'Sales - Vancouver.csv',
#  'Returns - Montreal.csv',
#  'Sales - Ottawa.csv',
#  'Returns - Ottawa.csv',
#  'Sales- Montreal.csv']

# %%
for file in list_file:
  print(f'/content/drive/MyDrive/Python/Sales/{file}')  #format / List files and path
# Out:
# /content/drive/MyDrive/Python/Sales/Sales- Toronto.csv
# /content/drive/MyDrive/Python/Sales/Returns - Vancouver.csv
# /content/drive/MyDrive/Python/Sales/Returns - Toronto.csv
# /content/drive/MyDrive/Python/Sales/Sales - Vancouver.csv
# /content/drive/MyDrive/Python/Sales/Returns - Montreal.csv
# /content/drive/MyDrive/Python/Sales/Sales - Ottawa.csv
# /content/drive/MyDrive/Python/Sales/Returns - Ottawa.csv
# /content/drive/MyDrive/Python/Sales/Sales- Montreal.csv

# %%
for file in list_file:
  if "sales" in file.lower():  #only sales files, lower or upper case
    spreadsheet = pd.read_csv(f'/content/drive/MyDrive/Python/Sales/{file}')
    print(file)               #Read what is inside the file / csv is the extension of the excel file
    display(spreadsheet)
# Out:
# Sales- Toronto.csv
#          Product  Items Sold First Name  Last Name        Date    Store  \
# 0         iPhone           4      Sarah      Souza   2/14/2018  Toronto
# 1     SmartWatch           3  Alexandre  Rodriguez   5/20/2018  Toronto
# 2         Camera           3    Camille      Silva   3/26/2018  Toronto
# 3         iPhone           3       Alon   Palmeira   11/6/2018  Toronto
# 4       Notebook           4    Leandro  Rodrigues    8/6/2018  Toronto
# ...          ...         ...        ...        ...         ...      ...
# 2221  SmartWatch           4       Joao     Junior   4/14/2018  Toronto
# 2222      iPhone           4       Itai     Puntel    5/2/2018  Toronto
# 2223      iPhone           1  Guilherme     Vianna   3/18/2018  Toronto
# 2224  SmartWatch           5    Antônio     Soares  11/21/2018  Toronto
# 2225          TV           5       Caio     Moraes   1/22/2018  Toronto
#
#       Unit Price
# 0           5300
# 1           1400
# 2           2100
# ...

# %%
total_spreadsheet = pd.DataFrame()  #all the spreadsheets will be added in total_spreadsheet

for file in list_file:
  if "sales" in file.lower():  #only sales files, lower or upper case
    spreadsheet = pd.read_csv(f'/content/drive/MyDrive/Python/Sales/{file}')
    total_spreadsheet = total_spreadsheet.append(spreadsheet)

 #adds each  excel spreadsheet in one big spreadsheet (total_spreadsheet)

display(total_spreadsheet)
# Out:
# <ipython-input-47-0508f56d715e>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-47-0508f56d715e>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-47-0508f56d715e>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# <ipython-input-47-0508f56d715e>:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#          Product  Items Sold First Name  Last Name       Date     Store  \
# 0         iPhone           4      Sarah      Souza  2/14/2018   Toronto
# 1     SmartWatch           3  Alexandre  Rodriguez  5/20/2018   Toronto
# ...

# %%
total_products = total_spreadsheet.groupby('Product').sum() # group by product column
display(total_products)
# Out:
# <ipython-input-48-5088e4ee512e>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#             Items Sold  Unit Price
# Product
# Android           1900     2145400
# Camera            1645     1182300
# Notebook          1794     2058000
# SmartWatch        1725      805000
# TV                3308     2707500
# Tablet            1650      889600
# iPhone            5175     9174300

# %%
from numpy import product
import plotly.express as px         # for graphs

# %%
graph = px.bar(total_products, x = total_products.index, y = 'Items Sold')
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

# %%
def bar_chart(numbers, labels, pos):
    plt.bar(pos, numbers, color=colors)
    plt.ylabel('Items Sold')
    plt.title('Total Products Sold in Canada')
    plt.xticks(ticks=pos, labels=labels)
    legend = plt.bar(pos, numbers, color=colors)
    plt.legend(legend, labels, loc = 'upper left', title='Product')
    plt.xlabel('Best selling electronics in Canadian stores')
    plt.show()

numbers = [1900, 1645, 1794, 3308, 1725, 1650, 5175]
colors = ['purple', 'brown', 'yellow', 'gray', 'olive', 'blue', 'red']
labels = ['Android', 'Camera', 'Notebook', 'TV', 'SmartWatch', 'Tablet', 'IPhone']
pos = list(range(7))
bar_chart(numbers, labels, pos)
